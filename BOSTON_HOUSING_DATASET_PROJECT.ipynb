# %% [markdown]
# <a href="https://colab.research.google.com/github/IndraniChilukuri/Data_Analysis/blob/main/BOSTON_HOUSING_DATASET_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#2 DATA EXPLORATION
sb.set(color_codes=True)
data=pd.read_csv("/content/housing.csv")
data
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
data.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
data.tail()
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0

# %%
data.shape
# Out:
# (489, 4)

# %%
data.columns
# Out:
# Index(['RM', 'LSTAT', 'PTRATIO', 'MEDV'], dtype='object')

# %%
data.nunique()
# Out:
# RM         430
# LSTAT      442
# PTRATIO     44
# MEDV       228
# dtype: int64

# %%
data['RM'].unique
# Out:
# <bound method Series.unique of 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 484    6.593
# 485    6.120
# 486    6.976
# 487    6.794
# 488    6.030
# Name: RM, Length: 489, dtype: float64>

# %%
#3 DATA PREPROCESSING
data.isna().sum()
# Out:
# RM         0
# LSTAT      0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %%
data.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06

# %%
fig,ax=plt.subplots(2,2,figsize=(8,12))
ax[0,0].boxplot(x='RM',data=data)
ax[0,0].set_title("RM")
ax[0,1].boxplot(x='LSTAT',data=data)
ax[0,1].set_title("LSTAT")
ax[1,0].boxplot(x='PTRATIO',data=data)
ax[1,0].set_title("PTRATIO")
ax[1,1].boxplot(x='MEDV',data=data)
ax[1,1].set_title("MEDV")
# Out:
# Text(0.5, 1.0, 'MEDV')

# %%
sb.boxplot(x='RM',data=data)
# Out:
# <Axes: xlabel='RM'>

# %%
Q1=data.RM.quantile(0.25)
Q3=data.RM.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# 0.6950000000000003

# %%
data=data[~((data.RM < (Q1 -1.5 * IQR))|(data.RM > (Q3 + 1.5 * IQR)))]

# %%
data
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [467 rows x 4 columns]

# %%
sb.boxplot(x='LSTAT',data=data)
# Out:
# <Axes: xlabel='LSTAT'>

# %%
Q1=data.LSTAT.quantile(0.25)
Q3=data.LSTAT.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# 9.515000000000002

# %%
data=data[~((data.LSTAT < (Q1 -1.5 * IQR))|(data.LSTAT > (Q3 + 1.5 * IQR)))]

# %%
data
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [463 rows x 4 columns]

# %%
sb.boxplot(x='PTRATIO',data=data)
# Out:
# <Axes: xlabel='PTRATIO'>

# %%
Q1=data.PTRATIO.quantile(0.25)
Q3=data.PTRATIO.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# 2.8000000000000007

# %%
data=data[~((data.PTRATIO < (Q1 -1.5 * IQR))|(data.PTRATIO > (Q3 + 1.5 * IQR)))]

# %%
data
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [451 rows x 4 columns]

# %%
sb.boxplot(x='MEDV',data=data)
# Out:
# <Axes: xlabel='MEDV'>

# %%
Q1=data.MEDV.quantile(0.25)
Q3=data.MEDV.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# 155400.0

# %%
data=data[~((data.MEDV < (Q1 -1.5 * IQR))|(data.MEDV > (Q3 + 1.5 * IQR)))]

# %%
data
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 5    6.430   5.21     18.7  602700.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [436 rows x 4 columns]

# %%
x=data.iloc[:,0:3]
x
# Out:
#         RM  LSTAT  PTRATIO
# 0    6.575   4.98     15.3
# 1    6.421   9.14     17.8
# 2    7.185   4.03     17.8
# 3    6.998   2.94     18.7
# 5    6.430   5.21     18.7
# ..     ...    ...      ...
# 484  6.593   9.67     21.0
# 485  6.120   9.08     21.0
# 486  6.976   5.64     21.0
# 487  6.794   6.48     21.0
# 488  6.030   7.88     21.0
#
# [436 rows x 3 columns]

# %%
y=data.iloc[:,3]
y
# Out:
# 0      504000.0
# 1      453600.0
# 2      728700.0
# 3      701400.0
# 5      602700.0
#          ...
# 484    470400.0
# 485    432600.0
# 486    501900.0
# 487    462000.0
# 488    249900.0
# Name: MEDV, Length: 436, dtype: float64

# %%
plt.figure(figsize = (16,6))
sb.boxplot(data = data)
# Out:
# <Axes: >

# %%
#4 EXPLORATORY DATA ANALYSIS
from mlxtend.plotting import scatterplotmatrix

cols = ['RM', 'LSTAT', 'PTRATIO', 'MEDV']
scatterplotmatrix(data[cols].values, figsize=(10, 8), names=cols, alpha=0.5)
plt.tight_layout()
plt.show()

# %%
correlation_matrix = data.corr().round(2)
sb.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 5))

features = ['LSTAT', 'RM']
target = data['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = data[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %%
prices=data.iloc[:,3]
minimum_price = np.min(prices)
maximum_price = np.max(prices)
mean_price = np.mean(prices)
median_price = np.median(prices)
std_price = np.std(prices)
print("Statistics for Boston housing dataset:\n")
print("Minimum price: ${:,.2f}".format(minimum_price))
print("Maximum price: ${:,.2f}".format(maximum_price))
print("Mean price: ${:,.2f}".format(mean_price))
print("Median price ${:,.2f}".format(median_price))
print("Standard deviation of prices: ${:,.2f}".format(std_price))
# Out:
# Statistics for Boston housing dataset:
#
# Minimum price: $117,600.00
# Maximum price: $737,100.00
# Mean price: $428,607.11
# Median price $429,450.00
# Standard deviation of prices: $124,307.13

# %%
with pd.option_context('float_format', '{:.2f}'.format):
    print(prices.describe())
# Out:
# count      436.00
# mean    428607.11
# std     124449.93
# min     117600.00
# 25%     348075.00
# 50%     429450.00
# 75%     499800.00
# max     737100.00
# Name: MEDV, dtype: float64

# %%
#5 FEATURE SELECTION
class LinearRegressionGD(object):

    def __init__(self, eta=0.001, n_iter=20):
        self.eta = eta
        self.n_iter = n_iter

    def fit(self, X, Y):
        self.w_ = np.zeros(1 + X.shape[1])
        self.cost_ = []
        for i in range(self.n_iter):
            output = self.net_input(X)
            errors = (Y - output)
            self.w_[1:] += self.eta * X.T.dot(errors)
            self.w_[0] += self.eta * errors.sum()
            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)
        return self

    def net_input(self, X):
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def predict(self, X):
        return self.net_input(X)

# %%
X = data[['RM']].values
Y= data['MEDV'].values

# %%
from sklearn.preprocessing import StandardScaler

sc_x = StandardScaler()
sc_y = StandardScaler()

X_std = sc_x.fit_transform(X)
Y_std = sc_y.fit_transform(Y[:, np.newaxis]).flatten()

# %%
lr = LinearRegressionGD()
lr.fit(X_std, Y_std)

# %%
def lin_regplot(X, Y, model):
    plt.scatter(X, Y, c='steelblue', edgecolor='white', s=70)
    plt.plot(X, model.predict(X), color='black', lw=2)
    return None

# %%
lin_regplot(X_std, Y_std, lr)
plt.xlabel('Average number of rooms [RM] (standardized)')
plt.ylabel('Price in $1000s [MEDV] (standardized)')
plt.show()

# %%
#6 TRAIN-TEST SPLIT
X = pd.DataFrame(np.c_[data['LSTAT'], data['RM'], data['PTRATIO']], columns = ['LSTAT','RM','PTRATIO'])
Y= data['MEDV']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (348, 3)
# (88, 3)
# (348,)
# (88,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=0)
print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
#7 LINEAR REGRESSION MODEL
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
slr = LinearRegression()
slr.fit(X, Y)
Y_pred = slr.predict(X)
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: -12031.937
# Intercept: 540827.737

# %%
#8 MODEL EVALUATION
Y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, Y_train_predict)))
r2 = r2_score(Y_train, Y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

Y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, Y_test_predict)))
r2 = r2_score(Y_test, Y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 68785.36642885789
# R2 score is 0.6918635204419348
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 69859.77393402478
# R2 score is 0.6856788946666408

# %%
#9 MODEL INTERPRETATION
print(lin_model.coef_)
# Out:
# [-11336.24660701  57680.52310924 -15566.52811057]

# %%
print(lin_model.intercept_)
# Out:
# 513532.7203279204

# %%
predicted=lin_model.predict(X_test)

# %%
print(X_test)
# Out:
#      LSTAT     RM  PTRATIO
# 153   7.39  6.510     14.7
# 393  10.29  6.513     20.2
# 54    5.77  6.383     17.3
# 188  16.03  5.807     18.6
# 196   9.71  6.951     17.4
# ..     ...    ...      ...
# 20   13.83  5.965     21.0
# 346  29.05  6.434     20.2
# 278   7.34  6.333     16.9
# 14    8.47  5.834     21.0
# 297   5.99  6.635     17.0
#
# [109 rows x 3 columns]

# %%
predicted.shape
# Out:
# (109,)

# %%
dframe=pd.DataFrame(Y_test,predicted)

# %%
df1=pd.DataFrame({'Actual price':Y_test,'Predicted price':predicted})

# %%
print(df1)
# Out:
#      Actual price  Predicted price
# 159      489300.0    576430.100118
# 446      424200.0    458112.121919
# 56       518700.0    546996.420099
# 205      470400.0    377226.062056
# 213      560700.0    533537.492782
# ..            ...              ...
# 21       411600.0    373919.659778
# 398      151200.0    240887.374246
# 318      474600.0    532541.098015
# 15       417900.0    427125.793064
# 337      514500.0    563707.896102
#
# [109 rows x 2 columns]

# %%
df1.head(20)
# Out:
#      Actual price  Predicted price
# 159      489300.0    576430.100118
# 446      424200.0    458112.121919
# 56       518700.0    546996.420099
# 205      470400.0    377226.062056
# 213      560700.0    533537.492782
# 13       428400.0    436139.665009
# 407      245700.0    325550.971821
# 279      598500.0    572651.748456
# 111      478800.0    508596.967111
# 390      585900.0    385052.554748
# 11       396900.0    473091.763936
# 376      289800.0    384333.471082
# 366      258300.0    239067.123389
# 170      474600.0    483797.121298
# 485      432600.0    436707.312243
# 164      499800.0    523355.645292
# 474      285600.0    340902.098879
# 360      279300.0    350188.448566
# 219      663600.0    583742.189815
# 259      434700.0    410724.228092

# %%
lin_model.score(X_test,Y_test)
# Out:
# 0.6856788946666408

# %%
graph=df1.head(20)

# %%
graph.plot(kind='bar')
# Out:
# <Axes: >

# %%
#10 FINE TUNING
from sklearn.preprocessing import PolynomialFeatures

def create_polynomial_regression_model(degree):
  poly_features = PolynomialFeatures(degree=degree)

  X_train_poly = poly_features.fit_transform(X_train)
  poly_model = LinearRegression()
  poly_model.fit(X_train_poly, Y_train)
  y_train_predicted = poly_model.predict(X_train_poly)
  y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))
  rmse_train = np.sqrt(mean_squared_error(Y_train, y_train_predicted))
  r2_train = r2_score(Y_train, y_train_predicted)
  rmse_test = np.sqrt(mean_squared_error(Y_test, y_test_predict))
  r2_test = r2_score(Y_test, y_test_predict)

  print("The model performance for the training set")
  print("-------------------------------------------")
  print("RMSE of training set is {}".format(rmse_train))
  print("R2 score of training set is {}".format(r2_train))

  print("\n")

  print("The model performance for the test set")
  print("-------------------------------------------")
  print("RMSE of test set is {}".format(rmse_test))
  print("R2 score of test set is {}".format(r2_test))


create_polynomial_regression_model(2)
# Out:
# The model performance for the training set
# -------------------------------------------
# RMSE of training set is 60524.556213546064
# R2 score of training set is 0.761430877251982
#
#
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 61988.92979382504
# R2 score of test set is 0.7525158053831267

# %%
#11 CONCLUSION
def performance_metric(Y_true, Y_predict):
  score = r2_score(Y_true, Y_predict)
  return score

# %%
score = performance_metric([3, -0.5, 2, 7, 4.2], [2.5, 0.0, 2.1, 7.8, 5.3])
print("Model has a coefficient of determination, R^2, of {:.3f}.".format(score))
# Out:
# Model has a coefficient of determination, R^2, of 0.923.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

def fit_model(X, Y):
    param_grid = {
        'max_depth': [2, 4, 6, 8, 10]
    }
    regressor = DecisionTreeRegressor()

    reg = GridSearchCV(regressor, param_grid, scoring='neg_mean_squared_error', cv=5)

    reg.fit(X, Y)

    print("Parameter 'max_depth' is {} for the optimal model.".format(reg.best_estimator_.get_params()['max_depth']))
    print("Best Score is {:.2f}".format(reg.best_score_))

fit_model(X_train, Y_train)
# Out:
# Parameter 'max_depth' is 4 for the optimal model.
# Best Score is -5091808278.55

# %%
import matplotlib.pyplot as pl
import numpy as np
from sklearn.model_selection import learning_curve
from sklearn.model_selection import validation_curve
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import ShuffleSplit, train_test_split
def ModelComplexity(X, Y):
    cv = ShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)
    cv.get_n_splits(X)

    max_depth = np.arange(1,11)

    train_scores, test_scores = validation_curve(DecisionTreeRegressor(), X, Y, \
        param_name = "max_depth", param_range = max_depth, cv = cv, scoring = 'r2')

    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    pl.figure(figsize=(7, 5))
    pl.title('Decision Tree Regressor Complexity Performance')
    pl.plot(max_depth, train_mean, 'o-', color = 'r', label = 'Training Score')
    pl.plot(max_depth, test_mean, 'o-', color = 'g', label = 'Validation Score')
    pl.fill_between(max_depth, train_mean - train_std, \
        train_mean + train_std, alpha = 0.15, color = 'r')
    pl.fill_between(max_depth, test_mean - test_std, \
        test_mean + test_std, alpha = 0.15, color = 'g')

    pl.legend(loc = 'lower right')
    pl.xlabel('Maximum Depth')
    pl.ylabel('Score')
    pl.ylim([-0.05,1.05])
    pl.show()

# %%
ModelComplexity(X_train, Y_train)

# %%
with pd.option_context('float_format', '{:.2f}'.format):
    print(prices.describe())
# Out:
# count      436.00
# mean    428607.11
# std     124449.93
# min     117600.00
# 25%     348075.00
# 50%     429450.00
# 75%     499800.00
# max     737100.00
# Name: MEDV, dtype: float64

# %%
with pd.option_context('float_format', '{:.2f}'.format):
  feature_columns = ['RM', 'LSTAT', 'PTRATIO']
  features = data[feature_columns]
  print(features.describe())
# Out:
#           RM  LSTAT  PTRATIO
# count 436.00 436.00   436.00
# mean    6.18  13.09    18.72
# std     0.47   6.36     1.91
# min     4.88   1.98    14.70
# 25%     5.88   7.87    17.60
# 50%     6.16  12.27    19.10
# 75%     6.48  17.15    20.20
# max     7.42  30.81    22.00

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, Y_train)
client_data = [[5, 17, 15],
               [4, 32, 22],
               [8, 3, 12]]

for i, price in enumerate(reg.predict(client_data)):
    print("Predicted selling price for Client {}'s home: ${:,.2f}".format(i+1, price))
# Out:
# Predicted selling price for Client 1's home: $1,203,922.46
# Predicted selling price for Client 2's home: $1,971,500.85
# Predicted selling price for Client 3's home: $409,085.98

# %% [markdown]
# This model is built from Boston housing dataset and so can be used to predict the prices of houses in Boston only and the reason being different cities will have different price ranges of houses.
